# %%
import fitz
import os
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import fitz
#       2 import os
#       3 import re
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# ModuleNotFoundError: No module named 'frontend'

# %%
# !pip install fitz
# Out:
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Collecting configobj (from fitz)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting configparser (from fitz)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: httplib2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from fitz) (0.31.2)
# Collecting nibabel (from fitz)
#   Downloading nibabel-5.4.2-py3-none-any.whl.metadata (8.9 kB)
# Collecting nipype (from fitz)
#   Downloading nipype-1.11.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from fitz) (2.3.5)
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from fitz) (2.3.3)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6.4-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from fitz) (1.16.3)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httplib2->fitz) (3.2.5)
# Requirement already satisfied: importlib-resources>=5.12 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nibabel->fitz) (6.5.2)
# Requirement already satisfied: packaging>=20 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nibabel->fitz) (25.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nibabel->fitz) (4.15.0)
# Collecting acres>=0.3.0 (from nipype->fitz)
#   Downloading acres-0.5.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: click>=6.6.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nipype->fitz) (8.3.1)
# Collecting etelemetry>=0.3.1 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: filelock>=3.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nipype->fitz) (3.20.1)
# Collecting looseversion!=1.2,>=1.0.1 (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nipype->fitz) (6.0.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nipype->fitz) (3.6.1)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting puremagic>=1.15 (from nipype->fitz)
#   Using cached puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Collecting pydot>=1.2.3 (from nipype->fitz)
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from nipype->fitz) (2.9.0.post0)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Downloading simplejson-4.1.1-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting traits>=6.2 (from nipype->fitz)
#   Downloading traits-7.1.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from click>=6.6.0->nipype->fitz) (0.4.6)
# Requirement already satisfied: requests in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from etelemetry>=0.3.1->nipype->fitz) (2.32.5)
# Collecting ci-info>=0.2 (from etelemetry>=0.3.1->nipype->fitz)
#   Downloading ci_info-0.4.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.2->nipype->fitz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pandas->fitz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pandas->fitz) (2025.3)
# Collecting pathlib>=1.0 (from pyxnat->fitz)
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests->etelemetry>=0.3.1->nipype->fitz) (2025.11.12)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Downloading nibabel-5.4.2-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.3 MB ? eta -:--:--
#    ------------ --------------------------- 1.0/3.3 MB 2.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.3 MB 2.6 MB/s eta 0:00:01
#    ------------------------- -------------- 2.1/3.3 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 2.6/3.3 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 2.6/3.3 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 2.6/3.3 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.9/3.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.9/3.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.9/3.3 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 3.1/3.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 1.4 MB/s  0:00:02
# Downloading nipype-1.11.0-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.2 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.2 MB 3.4 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.9/3.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.2 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 2.8 MB/s  0:00:01
# Downloading acres-0.5.0-py3-none-any.whl (12 kB)
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Downloading ci_info-0.4.0-py2.py3-none-any.whl (6.3 kB)
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading prov-2.1.1-py3-none-any.whl (425 kB)
# Using cached puremagic-1.30-py3-none-any.whl (43 kB)
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Downloading rdflib-7.6.0-py3-none-any.whl (615 kB)
#    ---------------------------------------- 0.0/615.4 kB ? eta -:--:--
#    ---------------------------------------- 615.4/615.4 kB 4.5 MB/s  0:00:00
# Downloading simplejson-4.1.1-cp311-cp311-win_amd64.whl (90 kB)
# Downloading traits-7.1.0-cp311-cp311-win_amd64.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/5.0 MB 4.2 MB/s eta 0:00:02
#    -------- ------------------------------- 1.0/5.0 MB 4.6 MB/s eta 0:00:01
#    -------------- ------------------------- 1.8/5.0 MB 3.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.0 MB 3.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.0 MB 3.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.0 MB 3.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.0 MB 3.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.0 MB 3.4 MB/s eta 0:00:01
#    ------------------ --------------------- 2.4/5.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------ --------------- 3.1/5.0 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 3.7/5.0 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 4.2/5.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 4.7/5.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.0/5.0 MB 1.8 MB/s  0:00:02
# Downloading pyxnat-1.6.4-py3-none-any.whl (110 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: puremagic, pathlib, looseversion, ci-info, traits, simplejson, rdflib, pydot, nibabel, configparser, configobj, acres, pyxnat, prov, etelemetry, nipype, fitz
#
#    ---- -----------------------------------  2/17 [looseversion]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    --------- ------------------------------  4/17 [traits]
#    ----------- ----------------------------  5/17 [simplejson]
#    ----------- ----------------------------  5/17 [simplejson]
#    ----------- ----------------------------  5/17 [simplejson]
#    ----------- ----------------------------  5/17 [simplejson]
#    ----------- ----------------------------  5/17 [simplejson]
#    ----------- ----------------------------  5/17 [simplejson]
#    ----------- ----------------------------  5/17 [simplejson]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    -------------- -------------------------  6/17 [rdflib]
#    ---------------- -----------------------  7/17 [pydot]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ------------------ ---------------------  8/17 [nibabel]
#    ----------------------- ---------------- 10/17 [configobj]
#    ------------------------- -------------- 11/17 [acres]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ---------------------------- ----------- 12/17 [pyxnat]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    ------------------------------ --------- 13/17 [prov]
#    -------------------------------- ------- 14/17 [etelemetry]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ----------------------------------- ---- 15/17 [nipype]
#    ------------------------------------- -- 16/17 [fitz]
#    ------------------------------------- -- 16/17 [fitz]
#    ---------------------------------------- 17/17 [fitz]
#
# Successfully installed acres-0.5.0 ci-info-0.4.0 configobj-5.0.9 configparser-7.2.0 etelemetry-0.3.1 fitz-0.0.1.dev2 looseversion-1.3.0 nibabel-5.4.2 nipype-1.11.0 pathlib-1.0.1 prov-2.1.1 puremagic-1.30 pydot-4.0.1 pyxnat-1.6.4 rdflib-7.6.0 simplejson-4.1.1 traits-7.1.0
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
class Resume:
    def __init__(self,filename,text):
       self.filename = filename
       self.text = text

students = []

# %%
def extract_text(filename):
    text = ""
    doc = fitz.open(filename)
    for page in doc:
        text = text + page.get_text()
    return text

# %%
folder_path = "./resume"
filenames = os.listdir(folder_path)
print(filenames)
# Out:
# ['resume.pdf']

# %%
for filename in filenames:
    text = extract_text(f"{folder_path}/{filename}")
    student = Resume(filename,text)
    students.append(student)

# %%
for student in students:
    print(student.filename)
    print(student.text)
    email = re.search(r'\S+@\S+', student.text).group()
    print(email)
# Out:
# resume.pdf
# Yash Kishor Maske
# +91-9325815724 • yash.kishor.maske@gmail.com
#  github.com/yash-maske
# ¯ linkedin.com/in/yash-maske07
# Education
# B.Tech in Computer Science and Engineering (AI)
# 2023 – 2027
# Vishwakarma Institute of Information Technology, Pune
# CGPA: 9.11/10
# HSC (12th)
# 2023
# J C Junior College, Karanja Lad — 79.33%, CET: 97.61 percentile
# SSC (10th)
# 2021
# Govind New English Public School, Washim — 96.80%
# Projects
# QR4Change:
# Smart QR-Based Civic Grievance Reporting System — React.js, Express.js,
# Django, MongoDB, AI/ML, CNN, NLP
# 
# Designed a scalable full-stack platform to streamline civic issue reporting using QR codes, integrated with
# deep learning (YOLOv11n, InceptionV3) for image verification and NLP-based (ELECTRA) urgency
# scoring. Enhanced transparency with real-time public dashboards and heatmaps.
# Farm Connect — React.js, Django, AI/ML, Python
# 
# Engineered a smart agriculture assistant with AI/ML-powered crop disease detection and integrated
# real-time APIs for weather forecasting and market data analysis.
# Startup & Investors Match Platform — React.js, Express.js, Django, MongoDB, AI
# 
# Architected an AI-powered full-stack platform to streamline matchmaking between verified startups and
# investors, enhancing pitch opportunities and networking efficiency.
# Experience
# Software Trainee Intern
# Sep 2024 – Mar 2025
# TDTL, Pune
# • Developed and deployed responsive, AI-integrated full-stack websites for client solutions.
# • Collaborated in a team environment to optimize frontend and backend workflows, enhancing development
# efficiency.
# • Contributed to the development of the ”Farm Connect” project, which was awarded “Best Startup Idea.”
# Skills
# • Programming: Python, C, C++, JavaScript
# • Frameworks: React.js, Django, Express.js
# • Libraries: Pandas, NumPy, Scikit Learn
# • Databases: SQL, MongoDB
# • Data Viz: Tableau, Power BI
# • Tools: GitHub, Docker, Postman, Figma, Canva, FlutterFlow
# Certifications
# Basic Certificate Course in Artificial Intelligence — CDAC, Pune (2024)
# Achievements
# • “Best Startup Idea” Award by IT Minister Ashish Shelar for the Farm Connect project (2025)
# • Top Ten Finalist at Elephant Tank D Y Patil PGDM competition.
# Activities
# • Participated in multiple inter-college hackathons (Niram 3.0, DSS’25), showcasing problem-solving and
# teamwork.
#
# yash.kishor.maske@gmail.com

# %%
import hashlib

# %%
class Block:
  def __init__(self, data, prev_hash):
    self.data = data
    self.prev_hash = prev_hash
    self.hash = self.calc_hash()

  def calc_hash(self):
    sha = hashlib.sha256()
    sha.update(self.data.encode('utf-8'))
    return sha.hexdigest()

# %%
class Blockchain:

  def __init__(self):
    self.chain = [self.create_genesis_block()]

  
  def create_genesis_block(self):
    return Block("This is the genesis block", "0")

  
  def add_block(self, data):
    prev_block = self.chain[-1]
    new_block = Block(data, prev_block.hash)
    self.chain.append(new_block)

# %%
blockchain = Blockchain()

# %%
for student in students:
    blockchain.add_block(student.text)

# %%
print("Blockchain:")

for block in blockchain.chain:
    print('Data :',block.data)
    print('Privious Hash :', block.prev_hash)
    print('Hash :', block.hash)
    print("**********************************************************************************************************************************************************************")
# Out:
# Blockchain:
# Data : This is the genesis block
# Privious Hash : 0
# Hash : 182af1c8e7371cf31550abdf82208288ec41122cdb0955c2c3e0583feb5bb883
# **********************************************************************************************************************************************************************
# Data : Yash Kishor Maske
# +91-9325815724 • yash.kishor.maske@gmail.com
#  github.com/yash-maske
# ¯ linkedin.com/in/yash-maske07
# Education
# B.Tech in Computer Science and Engineering (AI)
# 2023 – 2027
# Vishwakarma Institute of Information Technology, Pune
# CGPA: 9.11/10
# HSC (12th)
# 2023
# J C Junior College, Karanja Lad — 79.33%, CET: 97.61 percentile
# SSC (10th)
# 2021
# Govind New English Public School, Washim — 96.80%
# Projects
# QR4Change:
# Smart QR-Based Civic Grievance Reporting System — React.js, Express.js,
# Django, MongoDB, AI/ML, CNN, NLP
# 
# Designed a scalable full-stack platform to streamline civic issue reporting using QR codes, integrated with
# deep learning (YOLOv11n, InceptionV3) for image verification and NLP-based (ELECTRA) urgency
# scoring. Enhanced transparency with real-time public dashboards and heatmaps.
# Farm Connect — React.js, Django, AI/ML, Python
# 
# Engineered a smart agriculture assistant with AI/ML-powered crop disease detection and integrated
# real-time APIs for weather forecasting and market data analysis.
# Startup & Investors Match Platform — React.js, Express.js, Django, MongoDB, AI
# 
# Architected an AI-powered full-stack platform to streamline matchmaking between verified startups and
# investors, enhancing pitch opportunities and networking efficiency.
# Experience
# Software Trainee Intern
# Sep 2024 – Mar 2025
# TDTL, Pune
# • Developed and deployed responsive, AI-integrated full-stack websites for client solutions.
# • Collaborated in a team environment to optimize frontend and backend workflows, enhancing development
# efficiency.
# • Contributed to the development of the ”Farm Connect” project, which was awarded “Best Startup Idea.”
# Skills
# • Programming: Python, C, C++, JavaScript
# • Frameworks: React.js, Django, Express.js
# • Libraries: Pandas, NumPy, Scikit Learn
# • Databases: SQL, MongoDB
# • Data Viz: Tableau, Power BI
# • Tools: GitHub, Docker, Postman, Figma, Canva, FlutterFlow
# Certifications
# Basic Certificate Course in Artificial Intelligence — CDAC, Pune (2024)
# Achievements
# • “Best Startup Idea” Award by IT Minister Ashish Shelar for the Farm Connect project (2025)
# • Top Ten Finalist at Elephant Tank D Y Patil PGDM competition.
# Activities
# • Participated in multiple inter-college hackathons (Niram 3.0, DSS’25), showcasing problem-solving and
# teamwork.
#
# Privious Hash : 182af1c8e7371cf31550abdf82208288ec41122cdb0955c2c3e0583feb5bb883
# Hash : 7e140353dbf5c9026ce776900bb47c0654e40e0e22810eedb9f07cde9cbc5686
# **********************************************************************************************************************************************************************
